# %%
import sqlalchemy as sa

def create_mysql_engine():
    return sa.create_engine("mysql+pymysql://root:root@easywaze-mysql:3306")

# %%
engine = create_mysql_engine()

# %%
engine.execute('USE waze')
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1121             wait = use_overflow and self._overflow >= self._max_overflow
# -> 1122             return self._pool.get(wait, self._timeout)
#    1123         except sqla_queue.Empty:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sqlalchemy/util/queue.py in get(self, block, timeout)
#     144                 if self._empty():
# --> 145                     raise Empty
#     146             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# ...

# %%
engine.execute('SELECT * FROM waze.alerts')
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1121             wait = use_overflow and self._overflow >= self._max_overflow
# -> 1122             return self._pool.get(wait, self._timeout)
#    1123         except sqla_queue.Empty:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sqlalchemy/util/queue.py in get(self, block, timeout)
#     144                 if self._empty():
# --> 145                     raise Empty
#     146             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# ...

# %%
a = ['id', 
                        'start_time_millis', 
                        'end_time_millis', 
                        'start_time', 
                        'end_time', 
                        'city', 
                        'raw_json']

# %%
import json

# %%
a = '[{"city": "Joinville", "type": "WEATHERHAZARD", "uuid": "51aedbe8-31ff-38f9-b2bf-3c364beab0d4", "magvar": 358, "street": "SC-108 Rod. Rodolfo Jahn", "roadType": 6, "nThumbsUp": 3, "pubMillis": 1532355363709, "confidence":1, "reliability": 8, "reportRating": 2}]'

# %%
class Fish:
    def __init__(self, first_name, last_name="Fish"):
        self.first_name = first_name
        self.last_name = last_name
        
    def swim(self):
        print("The fish is swimming.")

class Trout(Fish):
    
    def __init__(self, a):
        self.a = a
        super().__init__(self)
        
a = Trout(1)
#a.swim()
a.first_name

# %%
json.dump(json.loads(a), open('test.json', 'w'))

# %%
from collections import defaultdict

# %%
a = "/Users/joaoc/Documents/Projects/easywaze/src/dumps/json/2018-06-24_to_2018-07-26/alerts_2018-07-23 14:25:00_joinville_1.json"

# %%
a = 'Tue Jul 24 20:29:11 +0000 2018'

# %%
datetime.strptime(a, '%a %b %d %H:%M:%S %z %Y')
# Out:
# datetime.datetime(2018, 7, 24, 20, 29, 11, tzinfo=datetime.timezone.utc)

# %%
def chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %%
ids = [1,2,3,4]
ids2 = [1,2,3]

# %%
list(set(ids) - set(ids).intersection(ids2))
# Out:
# [4]

# %%
"""
        SELECT *
        FROM `{table}`
        WHERE `ids`
            IN ({ids})
""".format(
    table=table,
    ids=','.join(map(str, ids))
)
# Out:
# '\n        SELECT *\n        FROM `alerts`\n        WHERE `ids`\n            IN (1,2,3,4)\n'

# %%
a = defaultdict(lambda: None)

# %%
a = ['a', 'b']
item_list = [e for e in a if e not in ('a')]

# %%
item_list
# Out:
# ['foo', 3.14, True]
